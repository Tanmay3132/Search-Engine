# %%
# %pip install PyGithub
# Out:
# Collecting PyGithub
#   Downloading PyGithub-1.57-py3-none-any.whl (297 kB)
#      -------------------------------------- 297.6/297.6 kB 3.1 MB/s eta 0:00:00
# Collecting pyjwt>=2.4.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Collecting pynacl>=1.4.0
#   Downloading PyNaCl-1.5.0-cp36-abi3-win_amd64.whl (212 kB)
#      -------------------------------------- 212.1/212.1 kB 3.3 MB/s eta 0:00:00
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests>=2.14.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from PyGithub) (2.27.1)
# Requirement already satisfied: cffi>=1.4.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pynacl>=1.4.0->PyGithub) (1.15.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.14.0->PyGithub) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.14.0->PyGithub) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.14.0->PyGithub) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.14.0->PyGithub) (2.0.12)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from deprecated->PyGithub) (1.14.0)
# Requirement already satisfied: pycparser in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub) (2.21)
# Installing collected packages: pyjwt, deprecated, pynacl, PyGithub
# Successfully installed PyGithub-1.57 deprecated-1.2.13 pyjwt-2.6.0 pynacl-1.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from github import Github 

g = Github()

userquery=input('Enter your search query-')

sort_flag=input('Do you want to sort the results based on the number of stars on the repositories? (y/n)-')
tup=[]
def extract_repos(userquery):
    
    repositories = g.search_repositories(query=userquery)
    for i in range(100):
        url='https://github.com/{}'.format(repositories[i].full_name)
        #print(url)
        stars_count=repositories[i].stargazers_count
       # print('Number of Stars on the repo=', stars_count)
        tup.append([url, stars_count])
        

def sortfun(Tuple):
    Tuple=sorted(Tuple, key=lambda x:x[1], reverse=True)
    return Tuple

def apply_sort(flag, Tuple):
    if(flag=='y'):
        new_tup=sortfun(Tuple)
    for i in  new_tup:
        print(i)
    
extract_repos(userquery)

apply_sort(sort_flag, tup)
# Out:
# Enter your search query-machine learning
# Do you want to sort the results based on the number of stars on the repositories? (y/n)-y
# ['https://github.com/tensorflow/tensorflow', 169427]
# ['https://github.com/josephmisiti/awesome-machine-learning', 56846]
# ['https://github.com/scikit-learn/scikit-learn', 52204]
# ['https://github.com/ZuzooVn/machine-learning-for-software-engineers', 26323]
# ['https://github.com/lutzroeder/netron', 20675]
# ['https://github.com/trekhleb/homemade-machine-learning', 20586]
# ['https://github.com/afshinea/stanford-cs-229-machine-learning', 14236]
# ['https://github.com/ty4z2008/Qix', 14048]
# ['https://github.com/onnx/onnx', 13724]
# ['https://github.com/EthicalML/awesome-production-machine-learning', 12702]
# ['https://github.com/ujjwalkarn/Machine-Learning-Tutorials', 12506]
# ['https://github.com/kubeflow/kubeflow', 12066]
# ['https://github.com/mindsdb/mindsdb', 11885]
# ['https://github.com/rasbt/python-machine-learning-book', 11724]
# ['https://github.com/ddbourgin/numpy-ml', 11521]
# ['https://github.com/dive-into-machine-learning/dive-into-machine-learning', 11078]
# ['https://github.com/ashishpatel26/500-AI-Machine-learning-Deep-learning-Computer-vision-NLP-Projects-with-code', 11004]
# ['https://github.com/sjwhitworth/golearn', 8617]
# ['https://github.com/timzhang642/3D-Machine-Learning', 8504]
# ['https://github.com/Yorko/mlcourse.ai', 8493]
# ['https://github.com/dotnet/machinelearning', 8212]
# ['https://github.com/unifyai/ivy', 7720]
# ['https://github.com/llSourcell/Learn_Machine_Learning_in_3_Months', 7554]
# ['https://github.com/chiphuyen/machine-learning-systems-design', 7513]
# ['https://github.com/deeplearning-ai/machine-learning-yearning-cn', 7366]
# ['https://github.com/ljpzzz/machinelearning', 7246]
# ['https://github.com/roboticcam/machine-learning-notes', 7218]
# ['https://github.com/lazyprogrammer/machine_learning_examples', 7091]
# ['https://github.com/instillai/machine-learning-course', 6872]
# ['https://github.com/Jack-Cherish/Machine-Learning', 6806]
# ['https://github.com/rasbt/python-machine-learning-book-2nd-edition', 6730]
# ['https://github.com/firmai/industry-machine-learning', 6642]
# ['https://github.com/stefan-jansen/machine-learning-for-trading', 6438]
# ['https://github.com/Vay-keen/Machine-learning-learning-notes', 6359]
# ['https://github.com/mrdbourke/machine-learning-roadmap', 6029]
# ['https://github.com/khangich/machine-learning-interview', 6026]
# ['https://github.com/src-d/awesome-machine-learning-on-source-code', 5709]
# ['https://github.com/dformoso/machine-learning-mindmap', 5656]
# ['https://github.com/soulmachine/machine-learning-cheat-sheet', 5608]
# ['https://github.com/rhiever/Data-Analysis-and-Machine-Learning-Projects', 5404]
# ['https://github.com/lawlite19/MachineLearning_Python', 5165]
# ['https://github.com/humphd/have-fun-with-machine-learning', 4955]
# ['https://github.com/shuhuai007/Machine-Learning-Session', 4796]
# ['https://github.com/aladdinpersson/Machine-Learning-Collection', 4513]
# ['https://github.com/wepe/MachineLearning', 4502]
# ['https://github.com/jobbole/awesome-machine-learning-cn', 3833]
# ['https://github.com/dotnet/machinelearning-samples', 3806]
# ['https://github.com/zotroneneis/machine_learning_basics', 3765]
# ['https://github.com/susanli2016/Machine-Learning-with-Python', 3749]
# ['https://github.com/udacity/machine-learning', 3730]
# ['https://github.com/rasbt/python-machine-learning-book-3rd-edition', 3678]
# ['https://github.com/Nyandwi/machine_learning_complete', 3652]
# ['https://github.com/Azure/MachineLearningNotebooks', 3517]
# ['https://github.com/Sakura-gh/ML-notes', 3288]
# ['https://github.com/TarrySingh/Artificial-Intelligence-Deep-Learning-Machine-Learning-Tutorials', 3243]
# ['https://github.com/allmachinelearning/MachineLearning', 3186]
# ['https://github.com/louisfb01/start-machine-learning', 3184]
# ['https://github.com/Sophia-11/Machine-Learning-Notes', 3173]
# ['https://github.com/Fafa-DL/Lhy_Machine_Learning', 3167]
# ['https://github.com/JustFollowUs/Machine-Learning', 3036]
# ['https://github.com/firmai/financial-machine-learning', 3002]
# ['https://github.com/jphall663/awesome-machine-learning-interpretability', 2785]
# ['https://github.com/tirthajyoti/Machine-Learning-with-Python', 2556]
# ['https://github.com/RedstoneWill/HsuanTienLin_MachineLearning', 2552]
# ['https://github.com/pbharrin/machinelearninginaction', 2326]
# ['https://github.com/krishnakumarsekar/awesome-quantum-machine-learning', 2147]
# ['https://github.com/luispedro/BuildingMachineLearningSystemsWithPython', 2111]
# ['https://github.com/ethen8181/machine-learning', 2075]
# ['https://github.com/dipanjanS/practical-machine-learning-with-python', 2000]
# ['https://github.com/fengdu78/machine_learning_beginner', 1932]
# ['https://github.com/jindongwang/MachineLearning', 1834]
# ['https://github.com/13o-bbr-bbq/machine_learning_security', 1763]
# ['https://github.com/ssusnic/Machine-Learning-Flappy-Bird', 1741]
# ['https://github.com/teddylee777/machine-learning', 1706]
# ['https://github.com/Ayatans/Machine-Learning-homework', 1538]
# ['https://github.com/DeqianBai/Hands-on-Machine-Learning', 1474]
# ['https://github.com/firmai/machine-learning-asset-management', 1443]
# ['https://github.com/luwill/Machine_Learning_Code_Implementation', 1328]
# ['https://github.com/robertmartin8/MachineLearningStocks', 1320]
# ['https://github.com/rasbt/machine-learning-book', 1290]
# ['https://github.com/https-deeplearning-ai/machine-learning-engineering-for-production-public', 1258]
# ['https://github.com/fengdu78/WZU-machine-learning-course', 1215]
# ['https://github.com/tsyw/MachineLearningNotes', 1177]
# ['https://github.com/Borye/machine-learning-coursera-1', 1133]
# ['https://github.com/atinesh-s/Coursera-Machine-Learning-Stanford', 1040]
# ['https://github.com/carefree0910/MachineLearning', 1012]
# ['https://github.com/hanmq/MachineLearning_Zhouzhihua_ProblemSets', 977]
# ['https://github.com/WillKoehrsen/machine-learning-project-walkthrough', 955]
# ['https://github.com/JWarmenhoven/Coursera-Machine-Learning', 859]
# ['https://github.com/krishnaik06/Machine-Learning-in-90-days', 851]
# ['https://github.com/lcdevelop/MachineLearningCourse', 809]
# ['https://github.com/csuldw/MachineLearning', 791]
# ['https://github.com/trainindata/deploying-machine-learning-models', 553]
# ['https://github.com/stedy/Machine-Learning-with-R-datasets', 438]
# ['https://github.com/xxg1413/MachineLearning', 408]
# ['https://github.com/Azure-Samples/Azure-MachineLearning-DataScience', 401]
# ['https://github.com/codeheroku/Introduction-to-Machine-Learning', 372]
# ['https://github.com/jbagnato/machine-learning', 364]
# ['https://github.com/vivienzou1/DL-Notes-for-Interview', 288]
# ['https://github.com/JerryKurata/MachineLearningWithPython', 249]
